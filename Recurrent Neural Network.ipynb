# %% [markdown]
# # Long Short Term Memory

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import math
import pandas
import keras

# %%
# Data Generation. Time step t is not required in the actual training of a RNN
# Construct a data set with 2 underlying trends and 2 random noise components
# y would be the actual data that we need to model using the LSTM

nSample =800
t = np.arange(0,nSample,1)
trend1 = np.exp(0.003*(t))
trend2 = np.sin(t/5)
randomComp1 = np.random.randn(nSample)*np.sin(t*np.random.rand(nSample)/2)
randomComp2 = np.random.randn(nSample)*np.cos(t*np.random.rand(nSample)/5)

y = trend1 + trend2 + randomComp1 + randomComp2

# %% [markdown]
# ## Data Visualization

# %%
plt.plot(y)
plt.xlabel('Time')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Setting Training Parameters

# %%
batch_size = 200
timeStep = 35

# %% [markdown]
# ## Setting placeholder

# %%
y = tf.placeholder(tf.float32, (batch_size,timeStep, 1))
ytarget = tf.placeholder(tf.float32, (batch_size, 1))

# %% [markdown]
# ## Setting up LSTM Model

# %%
def LSTM(input, weights, biases):
    
    tf

# %%
weights = {
    
    
    
    
    
    
}
